# %% [markdown]
# # Labrapport TFY4125 Fysikk Vår 2024
#
# Navn:  Hans Christian Larsen, Herman Rekstad, Peder August Stene Tulluan<br>
# Institutt for Fysikk, NTNU <br>
# Dato: 2/10-24

# %% [markdown]
# ## Sammendrag
# Labprosjektet gikk ut på å undersøke hvordan ei kule beveger seg på en bane, både eksperimentelt under reelle forhold og numerisk under ideelle forhold. Vi regnet ut energien, hastigheten og posisjonen, samt ulike krefter til kula, ved start, slutt og underveis i løypa. Det totale tapet i mekanisk energi ble eksperimentelt regnet ut til å være ΔE = (3.921 ± 0.67) mJ, noe som var et ganske lite tap. Det gir et greit grunnlag for å anta ren rulling i de numeriske bergningene. Potensiell energi-plottet viser at den eksperimentelle bergningen gir høyere verdi, noe som samsvarer med at denne grafen følger kula sitt sentrum. Dette er i motsetning til den numeriske grafen da man her tar utgangspunkt i banehøyden og ikke kula.

# %% [markdown]
# ## Ren rulling på krum bane - teoretisk grunnlag
# Figuren nedenfor viser ei kule som ruller på et krumt underlag, med krumning henholdsvis oppover (øverst) og nedover (nederst). I figuren angis tyngdekraften $Mg$ og de to komponentene av kontaktkraften fra underlaget på kula, henholdsvis normalkraften $N$ og friksjonskraften $f$. Dessuten er både hastigheten $v$, baneakselerasjonen $a$ og sentripetalakselerasjonen $a_\perp$ illustrert. Ved perfekt ren rulling - uten andre former for friksjon enn den statiske friksjonen $f$ som virker i kontaktpunktet mellom kula og underlaget - er kulas mekaniske energi bevart. Da er kulas hastighet entydig bestemt av endringen $y$ i den vertikale posisjonen til kulas massesenter via
# $$\frac{1}{2} (1+c) Mv^2 = Mgy,$$
# idet vi antar at kula starter med hastighet $v=0$ i høyden $y=0$. Dersom kula er kompakt med uniform massefordeling, er $c=2/5$, slik at
# $$v(y) = \sqrt{\frac{10}{7}gy}.$$
# Kulas baneakselerasjon blir dermed
# $$a = \frac{dv}{dt} = \frac{dv}{dy}\,\frac{dy}{dt} = \sqrt{\frac{5g}{14y}}\,v_y.$$
# Her er $v_y = v \sin\beta = \sqrt{10gy/7}\sin\beta$ slik at
# $$a = -\frac{5g\sin\beta}{7}.$$
# Her er $\beta$ banens lokale helningsvinkel, knyttet til banens geometriske form $y(x)$ ved at
# $$\frac{dy}{dx} = \tan\beta.$$
# Vi innser nå at de to siste ligningene har konsistente fortegn: Kula ruller åpenbart saktere og saktere i motbakke.
# Da er både $\sin\beta$ og $\tan\beta$ positive størrelser dersom $\beta > 0$.
# Friksjonskraften kan nå bestemmes ved hjelp av Newtons 2. lov:
# $$f - Mg\sin\beta = Ma = -\frac{5Mg\sin\beta}{7},$$
# dvs
# $$f = \frac{2Mg\sin\beta}{7}.$$
# Retningen på $f$ må være konsistent med at vinkelfarten øker i nedoverbakke og minker i oppoverbakke. Av den grunn peker $f$ alltid oppover langs banen. Vi ser at fortegnet stemmer: Motbakke og $\beta > 0$ gir $f>0$, dvs framover og oppover. Utforbakke og $\beta < 0$ gir $f<0$, dvs bakover og oppover. <br>
# Endelig kan normalkraften bestemmes ved hjelp av Newtons 2. lov i retning normalt på banen:
# $$N - Mg\cos\beta = M a_\perp = M v^2/R = Mv^2K.$$
# Her er $R$ banens krumningsradius og $K$ krumningen, gitt ved
# $$K = \frac{y''}{[1+(y')^2]^{3/2}},$$
# med $y' = dy/dx$ og $y'' = d^2y/dx^2$. Normalkraften har selvsagt retning oppover til enhver tid (dvs med positiv $y$-komponent). Sentripetalakselerasjonen har retning inn mot sentrum av den tenkte sirkelen med radius $R$. Når banen krummer oppover, er $y'' > 0$ og $K > 0$ i siste ligning. Det betyr at fortegnet stemmer: $N$ er større enn tyngdens normalkomponent $Mg\cos\beta$ når banen krummer oppover. Og omvendt: Når banen krummer nedover, er $y'' < 0$ og $K < 0$ i siste ligning. Det gir en normalkraft $N$ som er mindre enn tyngdens normalkomponent. Av erfaring vet vi at dette stemmer: Kjører vi fort nok på ski over en 'kul', kan vi helt miste kontakten med underlaget, dvs $N=0$. Her skal vi sørge for at baneformen $y(x)$ er slik at den rullende kula hele tiden har god kontakt med underlaget.

# %%
from IPython import display
display.Image("./krefter.png", width=400)

# %% [markdown]
# <b>Figur 1.</b> Kule som ruller på et krumt underlag. Her er $v$ kulas fart,
# $a$ er baneakselerasjon, $a_\perp$ er sentripetalakselerasjon, $Mg$ er tyngdekraft,
# $f$ er friksjonskraft og $N$ er normalkraft. Banens helningsvinkel $\beta$ er vinkelen mellom
# positiv $x$-akse (horisontal og mot høyre) og retningen til $v$. <br><br>

# %% [markdown]
# ## Baneform med kubiske *splines*
#
# Baneformen fastlegges ved hjelp av tredjegradspolynomer på de 7 intervallene mellom de 8 tilfeldig valgte skruefestehøydene, slik at både banen $y(x)$, banens deriverte $dy/dx$ og banens andrederiverte $d^2y/dx^2$ er kontinuerlige i skruefestene. Dette gjøres i Python med funksjonen CubicSpline fra SciPy-biblioteket interpolate med kommandoen
#
# *cs = CubicSpline(xfast,yfast,bc_type='natural')*
#
# Her er xfast og yfast tabeller (numpy arrays) med henholdsvis horisontale og vertikale koordinater for skruefestene, og med *bc_type='natural'* velges krumning lik null i de to ytterste skruefestene. Horisontal avstand mellom skruefestene er 200 mm slik at xfast = (0,0.200,...,1.400) m. Vertikale koordinater for skruefestene fastlegges ved å trekke tilfeldige tall med numpy-funksjonen random.randint.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import CubicSpline

#Tallverdier. Tryggest med SI-enheter fra start til mål!
M = 0.031    #kg
g = 9.81     #m/s**2
c = 2/5
h = 0.200    #m
xfast=np.asarray([0,1,2,3,4,5,6,7])*h
xmin = 0
xmax = 1.401
dx = 0.001
x = np.arange(xmin, xmax, dx)
Nx = len(x)

#Skruehøyder:
yfast = np.zeros(8)
"""
yfast[0] = 0.300
yfast[1] = yfast[0] - np.random.randint(40,60)/1000
yfast[2] = yfast[1] - np.random.randint(70,90)/1000
yfast[3] = yfast[2] + np.random.randint(-30,10)/1000
yfast[4] = yfast[3] + np.random.randint(30,70)/1000
yfast[5] = yfast[4] + np.random.randint(-20,20)/1000
yfast[6] = yfast[5] - np.random.randint(40,80)/1000
yfast[7] = yfast[6] + np.random.randint(-40,40)/1000
"""

#Kjør denne cellen så mange ganger dere vil, inntil dere får en baneform dere er fornøyd med.
#Når endelig baneform er valgt:
#Sett inn skruehøydene med 3 desimaler (m) og fjern kommentarsymbolet ("#") i neste linje.
yfast = np.asarray([0.3, 0.241, 0.158, 0.155, 0.207, 0.188, 0.114, 0.11])
#Når endelig baneform er valgt, kan dere gjerne legge inn # i starten på de 8 linjene som beregner yfast[] ovenfor

#Beregninger:
cs = CubicSpline(xfast, yfast, bc_type='natural')
#y = baneformen y(x)
y = cs(x)
#dydx = dy/dx = y'(x) (dimensjonsløs)
dydx = cs(x,1)
#d2ydx2 = y''(x) (enhet 1/m)
d2ydx2 = cs(x,2)
#K = 1/R = banens krumning (1/m)
K = d2ydx2/(1+dydx**2)**(1.5)
#beta = banens helningsvinkel (rad)
beta = np.arctan(dydx)
#betadeg = banens helningsvinkel (grader)
betadeg = beta*180/np.pi
#startvinkel = helningsvinkel i startposisjonen (grader)
startvinkel = betadeg[0]
#maksvinkel = banens maksimale helningsvinkel, i absoluttverdi (grader)
maksvinkel = np.max(np.abs(betadeg))

#Plotting av banens form y(x)
plt.figure(figsize=(15,4))
plt.plot(x,y)
plt.plot(xfast,yfast,'.',markersize=15)
plt.title('Banens form inklusive skruefestepunktene',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$y(x)$ [m]',fontsize=20)
plt.ylim(0,0.300)
plt.xlim(0,1.400)
plt.grid()
plt.show()

#Plotting av banens krumning
plt.figure(figsize=(15,4))
plt.plot(x,K)
plt.title('Banens krumning',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$K(x)$ [1/m]',fontsize=20)
plt.xlim(0,1.400)
plt.grid()
plt.show()


#Plotting av banens helningsvinkel
plt.figure(figsize=(15,4))
plt.plot(x,betadeg)
plt.title('Banens helningsvinkel',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel(r'$\beta$ [grader]',fontsize=20)
plt.ylim(-35,35)
plt.xlim(0,1.400)
plt.grid()
plt.show()

y37 = y[400:1400]
y27 = y[200:1400]
y37min = np.min(y37)
y37max = np.max(y37)
y27min = np.min(y27)
y27max = np.max(y27)
print('Bakketoppens høyeste punkt [m]: %6.3f' %y37max)
print('Banens laveste punkt [m]: %6.3f' %y27min)
print('Helningsvinkel i startposisjonen [grader]: %4.1f' %startvinkel)
print('Banens maksimale helningsvinkel [grader]: %4.1f' %maksvinkel)
print('De 8 festepunkthøydene [m]:', yfast)
yfast = np.asarray([0.3, 0.241, 0.158, 0.155, 0.207, 0.188, 0.114, 0.11])
# Out:
# Bakketoppens høyeste punkt (m):  0.212
# Banens laveste punkt (m):  0.104
# Helningsvinkel i startposisjonen (grader): -13.5
# Banens maksimale helningsvinkel (grader): 24.8
# De 8 festepunkthøydene (m): [0.3   0.241 0.158 0.155 0.207 0.188 0.114 0.11 ]

# %% [markdown]
# ## Numerisk beregnede fysiske størrelser
# I neste celle beregnes det sentrale fysiske størrelser med utgangspunkt i den valgte baneformen.
# * Kulas hastighet (m/s) som funksjon av horisontal posisjon $x$ (m):
# $$v(x)=\sqrt{\frac{10g[y(0)-y(x)]}{7}}$$
# * Normalkraft $N$ og friksjonskraft $f$ (N) som funksjon av $x$ (m) i samme figur: <br>
# $$N = Mg\cos\beta + M v^2K$$
# $$f = \frac{2Mg\sin\beta}{7}$$
# * Forholdet $|f/N|$ som funksjon av $x$ (m). <br>
# * Kulas hastighet $v$ (m/s) som funksjon av tid $t$ (s). <br>
# * Potensiell energi, kinetisk energi og total energi (J) som funksjon av $x$ (m). <br>

# %%
#Numerisk beregning og plotting av de fysiske størrelsene v(x), N(x), f(x), f/N|, v(t), Epot(x), Ekin(x), Etot(x)

v = np.sqrt(10*g*(y[0]-y)/7)

plt.plot(x,v)
plt.title('Kulas hastighet gitt horisontal forflytting',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$v(x)$ [$m/s$]',fontsize=20)
plt.ylim(0, 1.700)
plt.xlim(0,1.400)
plt.grid()
plt.show()

t = np.zeros(1401)
vx = np.zeros(1401)
dx = x[1]-x[0]
for z in range(1, 1401):
    t[z] = t[z-1] + 2*dx/(v[z-1]*np.cos(beta[z-1])+v[z]*np.cos(beta[z]))
plt.plot(t,v)
plt.title('Hastighet gitt tid',fontsize=20)
plt.xlabel('$t$ [s]',fontsize=20)
plt.ylabel('$Hastighet$ [$m/s$]',fontsize=20)
plt.ylim(0, 1.700)
plt.xlim(0, 1.42)
plt.grid()
plt.show()

N = M*g*np.cos(beta) + M*v**2*K
f = 2*M*g*np.sin(beta)/7
plt.plot(x,N, 'r-', label=r"Normalkraft")
plt.plot(x,f, 'b-', label=r"Friksjonskraft")
plt.title('Kulas normal- og friksjonskraft',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$F(x)$ [$N$]',fontsize=20)
plt.ylim(-0.1, .600)
plt.xlim(0,1.420)
plt.grid()
plt.legend()
plt.show()

plt.plot(x,abs(f/N))
plt.title('Forhold mellom friksjon og normalkraft',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$|f/N|$ [$1$]',fontsize=20)
plt.ylim(0, 1.700)
plt.xlim(0,1.600)
plt.grid()
plt.show()

Ek = (1+c)/2*M*v**2
Ep = M*g*y
E = Ek + Ep
plt.plot(x,Ek, "r-", label="Kinetisk energi")
plt.plot(x,Ep, "b-", label="Potensiell energi")
plt.plot(x,E, "y-", label="Totalenergi")
plt.title('Energi til kula',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$Energi$ [$J$]',fontsize=20)
plt.ylim(0, 0.100)
plt.xlim(0,1.400)
plt.grid()
plt.legend()
plt.show()


#Utskrift av rulletid, slutthastighet, total mekanisk energi
rulletid = t[1400]
sluttfart = v[1400]
print(f'Rulletiden er {round(rulletid, 3)} s \nSlutthastighet er {round(sluttfart,3)} m/s \nTotal mekanisk energi er {round(E[0],3)} J')
# Out:
# Rulletiden er 1.4272766568972368
# Slutthastighet er 1.631782548538342
# Total mekanisk energi er 0.091233

# %% [markdown]
# ## Numerisk vs eksperimentell bane
#
# Fra Tracker er det eksportert eksperimentelle tallverdier for (t,x,y) til en tekststreng.

# %%
# Lese data fra tekstfila
filinnhold = """
t	    x	        y	
0,000	5,964E-3	0,328
0,033	1,092E-2	0,327
0,067	1,661E-2	0,325
0,100	2,398E-2	0,324
0,133	3,271E-2	0,321
0,167	4,372E-2	0,317
0,200	5,231E-2	0,311
0,233	6,711E-2	0,307
0,267	8,383E-2	0,304
0,300	0,103	    0,297
0,333	0,124	    0,291
0,367	0,147	    0,284
0,400	0,172	    0,276
0,433	0,200	    0,268
0,467	0,230	    0,256
0,500	0,261	    0,241
0,533	0,295	    0,225
0,567	0,333	    0,211
0,600	0,376	    0,198
0,633	0,419	    0,188
0,667	0,465	    0,184
0,700	0,511	    0,185
0,733	0,556	    0,191
0,767	0,599	    0,199
0,800	0,639	    0,211
0,833	0,677	    0,222
0,867	0,713	    0,231
0,900	0,747	    0,242
0,933	0,780	    0,249
0,967	0,813	    0,251
1,000	0,845	    0,249
1,033	0,878	    0,243
1,067	0,912	    0,236
1,100	0,948	    0,225
1,133	0,983	    0,212
1,167	1,022	    0,194
1,200	1,063	    0,175
1,233	1,108	    0,160
1,267	1,158	    0,151
1,300	1,209	    0,146
1,333	1,260	    0,143
1,367	1,312	    0,142
1,400	1,362	    0,153
1,433	1,412	    0,159
"""

# Splitte linjene og fjerne første rad (overskrifter)
linjer = filinnhold.strip().split('\n')[1:]

tverdier= []
xverdier = []
yverdier = []

for line in linjer:
    tt, xx, yy = line.split()
    tverdier.append(float(tt.replace(',', '.')))
    xverdier.append(float(xx.replace(',', '.').replace('E', 'e'))) 
    yverdier.append(float(yy.replace(',', '.')))

t_eks = np.array(tverdier)
x_eks = np.array(xverdier)
y_eks = np.array(yverdier)

plt.figure(figsize=(15,4))
plt.plot(x,y, label="Numerisk")
plt.plot(x_eks,y_eks, label="Eksperimentell")
plt.plot(xfast,yfast,'.',markersize=15)
plt.title('Banens form inklusive skruefestepunktene',fontsize=20)
plt.xlabel('$x$ (m)',fontsize=20)
plt.ylabel('$y(x)$ (m)',fontsize=20)
plt.legend()
plt.ylim(0,0.350)
plt.xlim(0,1.400)
plt.grid()
plt.show()

# %% [markdown]
# ## Numerisk vs eksperimentell hastighet
#
# I neste celle brukes numpyfunksjonen gradient til å beregne den eksperimentelle hastigheten til kula, både komponentene $v_x$ og $v_y$ og absoluttverdien $v = \sqrt{v_x^2+v_y^2}$.
# ```python
# vx_exp = np.gradient(x_exp,t_exp)
# ```
# *På tilsvarende vis lages vy_exp, og deretter*
# ```python
# v_exp = np.sqrt(vx_exp**2+vy_exp**2)
# ```

# %%
#Beregning av eksperimentell v_x, v_y og v
vx_eks = np.gradient(x_eks, t_eks)
vy_eks = np.gradient(y_eks, t_eks)
v_eks = np.sqrt(vx_eks**2+vy_eks**2)

#Figurer som sammenligner numerisk og eksperimentell v(x), v(t) og x(t)
plt.plot(x, v, label="Numerisk")
plt.plot(x_eks, v_eks, label="Eksprimentell")
plt.title('Kulas hastighet gitt horisontal forflytting',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$v(x)$ [$m/s$]',fontsize=20)
plt.ylim(0, 1.700)
plt.xlim(0,1.400)
plt.legend()
plt.grid()
plt.show()


plt.plot(t, v, label="Numerisk")
plt.plot(t_eks, v_eks, label="Eksprimentell")
plt.title('Hastighet gitt tid',fontsize=20)
plt.xlabel('$t$ [s]',fontsize=20)
plt.ylabel('$Hastighet$ [$m/s$]',fontsize=20)
plt.ylim(0, 1.700)
plt.xlim(0, 1.42)
plt.legend()
plt.grid()
plt.show()

plt.plot(t, x, label="Numerisk")
plt.plot(t_eks, x_eks, label="Eksprimentell")
plt.title('x-posisjon gitt tid',fontsize=20)
plt.xlabel('$t$ [s]',fontsize=20)
plt.ylabel('$Posisjon$ [$m$]',fontsize=20)
plt.ylim(0, 1.700)
plt.xlim(0, 1.42)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Numeriske vs eksperimentelle mekaniske energier
#
# *I neste celle beregnes eksperimentelle mekaniske energier: Kinetisk energi (translasjonsenergi og rotasjonsenergi), potensiell energi og total mekanisk energi. Sammenligning av numerisk og eksperimentell total mekanisk, kinetisk og potensiell energi.*

# %%
#Eksprimentelle verdier
x_start = np.array([0.005964, 0.0009212, 0.002769, 0.002144, 8.608e-05, 0.0006389, 0.001131, 0.0005198])
y_start = np.array([0.328, 0.326, 0.322, 0.319, 0.318, 0.317, 0.318, 0.315])
x_slutt = np.array([1.412, 1.356, 1.38, 1.357, 1.375, 1.369, 1.416, 1.368])
y_slutt = np.array([0.159, 0.151, 0.147, 0.148, 0.152, 0.146, 0.149, 0.142])
v_slutt = np.array([1.52602, 1.52602, 1.46993, 1.47989, 1.49225, 1.48577, 1.465865, 1.465865])
tid = [1.433, 1.433, 1.433, 1.433, 1.433, 1.433, 1.433, 1.433]

#Beregning av eksperimentell Etrans_exp, Erot_exp, Ekin_exp, Epot_exp, Etot_exp
Ek_eks = (1+c)/2*M*v_eks**2
Ep_eks = M*g*y_eks
E_eks = Ek_eks + Ep_eks

#Figurer som sammenligner numerisk og eksperimentell kinetisk, potensiell og total mekanisk energi
plt.plot(x,Ek, "r-", label="Kinetisk energi")
plt.plot(x,Ep, "b-", label="Potensiell energi")
plt.plot(x,E, "y-", label="Totalenergi")
plt.plot(x_eks,Ek_eks, "m-", label="Kinetisk energi eksperimentell")
plt.plot(x_eks,Ep_eks, "c-", label="Potensiell energi eksperimentell")
plt.plot(x_eks,E_eks, "g-", label="Totalenergi eksperimentell")
plt.title('Energien til kula',fontsize=20)
plt.xlabel('$x$ [m]',fontsize=20)
plt.ylabel('$Energi$ [$J$]',fontsize=20)
plt.ylim(0, 0.100)
plt.xlim(0,1.400)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Det fremgår av grafen at den potensielle energien til kula i det eksperimentelle forsøket konsekvent ligger over verdien fra det numeriske. Det passer bra med at under analysen av det eksprimentelle forsøket fulgte programmet kula og brukte dens høyde, mens vi så på høyden til selve banen under den numeriske. Årsaken til at den kinetiske energien ikke samsvarer er ikke like tydelig, men er trolig en konsekvens av flere forhold. Sannsynligvis har ikke kula rullet utelukkende perfekt, noe som kan ha ført til noe glidefriksjon. Eventuelt er det sannsynlig at tracket har hatt enkelte målefeil, både knyttet til hvordan den følger ballen og generell kalibrering.
#
# ## Er den mekaniske energien bevart i rulleforsøkene?
# For hvert rulleforsøk ble det brukt posisjons- og fartsdata i start- og sluttpunktet fra Tracker til å beregne total mekanisk energi $E_i$ i startposisjonen (ved $x=0$) og $E_f$ i sluttposisjonen (ved $x=1.40$ m) til å måle tap av mekanisk energi.

# %%
#Beregning av Delta E = E_i - E_f for 8 vellykkede rulleforsøk
E_i = M*g*y_start
E_f = (1+c)*M*v_slutt**2/2 + M*g*y_slutt
dE = E_i-E_f

#Beregning av middelverdi og standardfeil for Delta E
dE_avg = np.mean(dE)
dE_std = np.sqrt(sum((dE-dE_avg)**2)/(len(dE)-1))
dE_se = dE_std/np.sqrt(len(dE))

#Utskrift av Delta E på formen Delta E = (Middelverdi +- Standardfeil) mJ
print(f'Tapet av mekanisk energi gitt med usikkerhet er: \u0394E = ({round(dE_avg*1000, 3)} ± {round(dE_se*1000, 3)}) mJ')
# Out:
# Tapet av mekanisk energi gitt med usikkerhet er: ΔE = (3.921 ± 0.67) mJ

# %% [markdown]
# ## Noen avsluttende betrakninger

# %% [markdown]
# $\Delta$ E er ganske lav relativt til total mekanisk energi. Tapet er kun på 4mJ, noe som tilsvarer 4% av totalen på om lag 100mJ. Det betyr at antagalsen om at kula ruller rent er ganske god. Dersom kula ikke hadde oppfylt rullebetinglsen v = $\omega$ $\cdot$ r, ville kula i større grad sklidd og fått et større friksjonstap.
#
# Grafen til friksjonskrafta stemmer også bra. I starten når kula triller nedover må friksjonskraften virke tangentielt samme retning som vinkelakselerasjonen i angrepspunktet med kontaktflata, fordi vinkelhastigheten må økes for å oppfylle rullebetingelsen. I tillegg skifter friksjonskrafta fortegn i toppunktet og forblir positiv helt til bunnpunktet. Det er fordi vinkelakselerasjonen her må minke i likhet med translasjonsakselerasjonen. Etter bunnpunktet skifter det igjen fortegn med samme argumentasjon som i startfasen. Ergo betyr negativ friksjon en kraft mot venstre og positiv mot høyre.
#
# Normalkrafta har også forventet utvikling fordi den er stor i bunnpunkt og lavere i toppunkt. Dersom man antar en sirkelbevegelse i disse punktene og således tenker at normalkrafta peker inn mot sentrum i sirkelen, vil tyngden virke med og mot normalkrafta i henholdsvis topp- og bunnpunkt.
#
# Friksjonskoeffisienten må minst være like stor som høyeste verdi i |f/N|-plottet. f/N gir friksjonskoeffisienten. Dermed må nødvendigvis koeffisenten være stor nok til å gi en friksjon slik at kula ikke glipper her. Dersom man tar koeffisienten fra et annet punkt vil produktet $\mu_s \cdot N$ ikke bli tilstrekkelig stor når friksjonen skal nå sin høyest verdi. $\mu_s \ge 0,14$
#
# Det er rimelig at K(x) har knekkpunktet hver 20. cm fordi det er et nytt skruepunkt som gir en ny baneform frem til neste skruepunkt. Krumninga på banen mellom opphenga blir derfor uavhengig av krumninga før, og det fører til knekkpunkt.
#
# Antagalsen om at kula er liten i forhold til banen stemmer bra overalt. Hvis man ser på det mest kritiske tilfellet der radiusen er minst, blir det der krumninga er størst, altså når K(x) = 3. Da blir baneradiusen 1/3m ≈ 0,33 cm, som er betydelig større en kula sin radius.
